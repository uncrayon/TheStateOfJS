# %%
from collections import Counter
from user_agents import parse
import matplotlib.pyplot as plt
import seaborn as sbn
import pandas as pd
import numpy as np
import ndjson
import json

# %% [markdown]
# # Now let' try to reply all the later analysis.

# %%
with open('state-of-js-2019/state_of_js_2018_normalized_responses_anon.ndjson') as file:
    data = ndjson.load(file)

# %%
df = pd.read_json(ndjson.dumps(data),lines=True)

# %%
df.happiness[0]
# Out:
# {'javascript_flavors': 2,
#  'front_end_frameworks': 3,
#  'data_layer': 2,
#  'backend_frameworks': 2,
#  'testing': 1,
#  'mobile_desktop': 2}

# %% [markdown]
# # Let's do the grahs

# %%
A = {}
names, _ = list(zip(*list(df.tools[0].items())))
for i in df.tools:
    if len(i)>1:
        for j in names:
            try:
                if (j,i[j]['experience']) in A:
                    A[(j,i[j]['experience'])] += 1
                else:
                    A[(j,i[j]['experience'])] = 1
            except:
                pass

# %%
A= list(A.items())
A.sort(key=lambda x:x[0])

# %%
DF = {}
DF['framework'] = []
for i in np.sort(names):
    for j in A:
        if i == j[0][0]:
            if j[0][0] in DF['framework']:
                pass
            else:
                DF['framework'].append(j[0][0])
            try:
                DF[j[0][1]].append(j[1])
            except:
                DF[j[0][1]] = [j[1]]

# %%
Clean_Data_Interes = pd.DataFrame(DF)

# %%
Clean_Data_Interes.head()
# Out:
#        framework  interested  never_heard  not_interested  would_not_use  \
# 0        angular        2090           21            6413           6826
# 1         apollo        7116         8509            2108            170
# 2            ava        1735        14408            2675            320
# 3  clojurescript        3242         5312           10925            180
# 4        cordova        2356         2764            8878           3911
#
#    would_use
# 0       4812
# 1       2226
# 2        805
# 3        466
# 4       2040

# %%
sbn.set()
f,ax = plt.subplots(1,1,figsize=(10,5),dpi=120)
ax = Clean_Data_Interes.set_index('framework').plot(kind='bar', stacked=True,ax=ax)
ax.set_title('2018')
f.tight_layout()
f.savefig(fname='img/2018/framework_dist2018.png',format = 'png',dpi=150)
plt.show()

# %%
sbn.set()
f,ax = plt.subplots(1,1,figsize=(10,5),dpi=120)
ax = Clean_Data_Interes[['framework','interested','never_heard']].sort_values('interested').set_index('framework').plot(kind='bar',stacked=True,ax=ax)
ax.set_title('2018')
f.tight_layout()
f.savefig(fname='img/2018/framework_interesed_dist2018.png',format = 'png',dpi=150)
plt.show()

# %%
sbn.set()
f,ax = plt.subplots(1,1,figsize=(10,5),dpi=120)
ax = Clean_Data_Interes[['framework','interested','never_heard']].sort_values('interested').set_index('framework').plot(kind='bar',stacked=True,ax=ax)
ax.set_title('2018')
f.tight_layout()
f.savefig(fname='img/2018/framework_interesed_dist2018.png',format = 'png',dpi=150)
plt.show()

# %%
sbn.set()
f,ax = plt.subplots(1,1,figsize=(10,5),dpi=120)
ax = Clean_Data_Interes[['framework','would_use','would_not_use']].sort_values('would_use').set_index('framework').plot(kind='bar',stacked=True,ax=ax)
ax.set_title('2018')
f.tight_layout()
f.savefig(fname='img/2018/framework_would_use_dist2018.png',format = 'png',dpi=150)
plt.show()

# %%
dummy = {}
for i in df.user_info:
    for j in i:
        if 'company_size' in i and 'years_of_experience' in i and 'yearly_salary' in i:
            try:
                dummy[j].append(i[j])
            except:
                dummy[j] = [i[j]]

# %%
Data_Info = pd.DataFrame(dummy, columns=['years_of_experience','company_size','yearly_salary','user_agent'])

# %%
Data_Info['user_agent'] = Data_Info['user_agent'].apply(lambda x:str(parse(x)))

# %%
dummy = Counter(Data_Info.years_of_experience)
YOE = {}
YOE['years_of_experience'] = []
YOE['number_of_per'] = []
for i in dummy:
    YOE['years_of_experience'].append(i)
    YOE['number_of_per'].append(dummy[i])
YOE = pd.DataFrame(YOE)

# %%
YOE
# Out:
#   years_of_experience  number_of_per
# 0                 1_2           1958
# 1                5_10           5509
# 2         less_than_1            475
# 3                 2_5           5498
# 4               10_20           4719
# 5        more_than_20           1376

# %%
YOE['class'] = np.array([2,4,1,3,5,6])

# %%
f,ax = plt.subplots(1,1,figsize=(9,9),dpi=120)
ax = YOE.set_index('years_of_experience').sort_values('class').plot(kind='bar',y='number_of_per',ax=ax)
ax.set_xlabel('Years of Experience')
ax.set_title('2018')
f.tight_layout()
f.savefig(fname='img/2018/dist_yoe_2018.png',format = 'png',dpi=150)
plt.show()

# %%
dummy = Counter(Data_Info.company_size)
CZ = {}
CZ['company_size'] = []
CZ['count'] = []
for i in dummy:
    CZ['company_size'].append(i)
    CZ['count'].append(dummy[i])
CZ = pd.DataFrame(CZ)

# %%
CZ
# Out:
#      company_size  count
# 0           20_50   2596
# 1               1   1956
# 2  more_than_1000   3432
# 3             1_5   1709
# 4        100_1000   4041
# 5            5_10   1612
# 6           10_20   1928
# 7          50_100   2261

# %%
CZ['class'] = np.array([5,1,8,2,7,3,4,6])

# %%
f,ax = plt.subplots(1,1,figsize=(9,9),dpi=120)
ax = CZ.set_index('company_size').sort_values('class').plot(kind='bar',y='count',ax=ax)
ax.set_xlabel('Company Size')
ax.set_title('2018')
f.tight_layout()
f.savefig(fname='img/2018/dist_cz_2018.png',format = 'png',dpi=150)
plt.show()

# %%
dummy = Counter(Data_Info.yearly_salary)
YS = {}
YS['yearly_salary'] = []
YS['count'] = []
for i in dummy:
    YS['yearly_salary'].append(i)
    YS['count'].append(dummy[i])
YS = pd.DataFrame(YS)

# %%
YS
# Out:
#    yearly_salary  count
# 0         50_100   5972
# 1  work_for_free   1127
# 2        100_200   4258
# 3          30_50   3387
# 4          10_30   2906
# 5           0_10   1398
# 6  more_than_200    487

# %%
YS['class'] = np.array([5,1,6,4,3,2,7])

# %%
f,ax = plt.subplots(1,1,figsize=(9,9),dpi=120)
ax = YS.set_index('yearly_salary').sort_values('class').plot(kind='bar',y='count',ax=ax)
ax.set_xlabel('Yearly Salary')
ax.set_title('2018')
f.tight_layout()
f.savefig(fname='img/2018/dist_ys_2018.png',format = 'png',dpi=150)
plt.show()

# %%
Data_Info['Class_YOE'] = Data_Info['years_of_experience']
Data_Info['Class_YS'] = Data_Info['yearly_salary']
Data_Info['Class_CZ'] = Data_Info['company_size']

# %%
def detDict(DF,column):
    Dict = {}
    for i,j in zip(DF[column],DF['class']):
        Dict[i] = j-1
    return Dict

# %%
Data_Info['Class_YOE'] = Data_Info['Class_YOE'].replace(detDict(YOE,'years_of_experience'))
Data_Info['Class_YS'] = Data_Info['Class_YS'].replace(detDict(YS,'yearly_salary'))
Data_Info['Class_CZ'] = Data_Info['Class_CZ'].replace(detDict(CZ,'company_size'))

# %%
htmap_CYOE_CYS = np.zeros((len(YOE),len(YS)))
for i,j in zip(Data_Info['Class_YOE'],Data_Info['Class_YS']):
    htmap_CYOE_CYS[i,j] += 1

f,ax = plt.subplots(1,1,figsize=(9,9),dpi=120)
ax = sbn.heatmap(htmap_CYOE_CYS,ax=ax,\
                 xticklabels=YS.sort_values('class')['yearly_salary'],\
                yticklabels=YOE.sort_values('class')['years_of_experience'])
ax.tick_params(axis = 'y', rotation = 0)
ax.set_xlabel('Yearly salary')
ax.set_ylabel('Years of experience')
ax.set_title('2018')
f.tight_layout()
f.savefig(fname='img/2018/hp_yoe_ys_2018.png',format = 'png',dpi=150)
plt.show()

# %%
htmap_CZ_CYS = np.zeros((len(YS),len(CZ)))
for i,j in zip(Data_Info['Class_YS'],Data_Info['Class_CZ']):
    htmap_CZ_CYS[i,j] += 1
    
f,ax = plt.subplots(1,1,figsize=(9,9),dpi=120)
ax = sbn.heatmap(htmap_CZ_CYS,ax=ax,\
                 xticklabels=CZ.sort_values('class')['company_size'],\
                yticklabels=YS.sort_values('class')['yearly_salary'])
ax.tick_params(axis = 'y', rotation = 0)
ax.set_ylabel('Yearly salary')
ax.set_xlabel('Company size')
ax.set_title('2018')
f.tight_layout()
f.savefig(fname='img/2018/hp_ys_cs_2018.png',format = 'png',dpi=150)
plt.show()

# %%
htmap_CZ_CYOE = np.zeros((len(YOE),len(CZ)))
for i,j in zip(Data_Info['Class_YOE'],Data_Info['Class_CZ']):
    htmap_CZ_CYOE[i,j] += 1

f,ax = plt.subplots(1,1,figsize=(9,9),dpi=120)
ax = sbn.heatmap(htmap_CZ_CYOE,ax=ax,\
                 xticklabels=CZ.sort_values('class')['company_size'],\
                yticklabels=YOE.sort_values('class')['years_of_experience'])
ax.tick_params(axis = 'y', rotation = 0)
ax.set_xlabel('Company size')
ax.set_ylabel('Years of experience')
ax.set_title('2018')
f.tight_layout()
f.savefig(fname='img/2018/hp_cs_yoe_2018.png',format = 'png',dpi=150)
plt.show()

# %%
dummy = {}
for i in Data_Info.user_agent.apply(lambda x: x.split('/')):
    try:
        dummy[i[0].replace(' ','')] +=1
    except:
        dummy[i[0].replace(' ','')] = 1

dum = {}
for i in dummy:
    if i == 'PC':
        pass
    else:
        try:
            dum['mobile'] += 1
        except:
            dum['mobile'] = 1
        
dum['PC'] = dummy['PC']

dummy = {}
dummy['dispositive'] = []
dummy['Number_of_Users'] = []
for i in dum:
    dummy['dispositive'].append(i)
    dummy['Number_of_Users'].append(dum[i])

Data_Disp = pd.DataFrame(dummy)
f,ax = plt.subplots(1,1,figsize=(9,9),dpi=120)
ax = Data_Disp.set_index('dispositive').plot(kind='pie',subplots=True,ax=ax)
f.tight_layout()
f.savefig(fname='img/2018/pie_disp_2018.png',format = 'png',dpi=150)
plt.show()

# %%
dummy = {}
for i in Data_Info.user_agent.apply(lambda x: x.split('/')):
    try:
        dummy[i[1].replace(' ','')[:6]] +=1
    except:
        dummy[i[1].replace(' ','')[:6]] = 1
        
dum = {}
for i in dummy:
    if 'iOS' in i:
        try:
            dum['iOS'] += dummy[i]
        except:
            dum['iOS'] = dummy[i]
    else:
        dum[i] = dummy[i]

dummy={}
dummy['OS'] = []
dummy['Number_of_Users'] = []
dummy['Mobile'] = []
for i in dum:
    if 'Andro' in i or 'iOS' in i:
        dummy['Mobile'].append(1)
    else:
        dummy['Mobile'].append(0)
    dummy['OS'].append(i)
    dummy['Number_of_Users'].append(dum[i])

Data_OS = pd.DataFrame(dummy)

# %%
Data_OS
# Out:
#         OS  Number_of_Users  Mobile  Open_Source
# 0   Ubuntu              414       0            1
# 1   MacOSX             7269       0            0
# 2    Linux             1282       0            1
# 3   Window             4301       0            0
# 4   Androi             3338       1            1
# 5      iOS             2823       1            1
# 6   Chrome               37       0            0
# 7   Fedora               67       0            1
# 8   FreeBS                1       0            1
# 9   Gentoo                1       0            1
# 10  Firefo                1       0            1
# 11   Maemo                1       0            1

# %%
Data_OS['Open_Source'] = [1,0,1,0,1,0,0,1,1,1,1,1]

# %%
Data_OS['Open_Source'] = Data_OS['Open_Source'].replace({0:'Non OSS',1:'OSS'})

# %%
f,ax = plt.subplots(1,1,figsize=(9,9),dpi=120)
Data_OS[Data_OS.Mobile==1].groupby(by='Open_Source').agg({'Number_of_Users':'sum'}).plot(kind='bar',y='Number_of_Users',ax=ax)
ax.set_title('2018')
ax.set_xlabel('')
f.tight_layout()
f.savefig(fname='img/2018/dist_noss_oss_2018_mobile.png',format='png',dpi=150)
plt.show()

# %%
f,ax = plt.subplots(1,1,figsize=(9,9),dpi=120)
Data_OS[Data_OS.Mobile==0].groupby(by='Open_Source').agg({'Number_of_Users':'sum'}).plot(kind='bar',y='Number_of_Users',ax=ax)
ax.set_title('2018')
ax.set_xlabel('')
f.tight_layout()
f.savefig(fname='img/2018/dist_noss_oss_2018_pc.png',format='png',dpi=150)
plt.show()

# %%
f,ax = plt.subplots(1,1,figsize=(9,9),dpi=120)
Data_OS[Data_OS.Mobile==0].set_index('OS').plot(kind='bar',y='Number_of_Users',ax=ax)
ax.set_title('2018')
ax.set_xlabel('')
f.tight_layout()
f.savefig(fname='img/2018/dist_os_2018_pc.png',format='png',dpi=150)
plt.show()

# %%
f,ax = plt.subplots(1,1,figsize=(9,9),dpi=120)
Data_OS[Data_OS.Mobile==1].set_index('OS').plot(kind='bar',y='Number_of_Users',ax=ax)
ax.set_title('2018')
ax.set_xlabel('')
f.tight_layout()
f.savefig(fname='img/2018/dist_os_2018_mobile.png',format='png',dpi=150)
plt.show()

# %% [markdown]
# # Now let's work on FEND

# %%
dummy = {}
for i in df[df.sections_other_tools != {}].sections_other_tools:
    for j in i:
        try:
            dummy[j] = dummy[j]+i[j]
        except:
            dummy[j] = i[j]

fw_dicts = {}
for i in dummy.keys():
    dum = {}
    dum['framework'] = []
    dum['Count'] = []
    for j,k in Counter(dummy[i]).items():
        dum['framework'].append(j)
        dum['Count'].append(k)
    fw_dicts[i] = pd.DataFrame(dum)
    
for i in fw_dicts:
    fw_dicts[i] = fw_dicts[i].sort_values('Count',ascending=False)

# %%
for i in fw_dicts.keys():
    f,ax = plt.subplots(1,1,figsize=(15,7),dpi=120)
    ax = sbn.barplot(x='framework',y='Count',data=fw_dicts[i])
    ax.tick_params(axis = 'x', rotation = 90)
    ax.set_title('2018 '+i)
    f.tight_layout()
    f.savefig(fname='img/2018/'+i+'dist_2018.png',format='png',dpi=150)
    plt.show()

# %% [markdown]
# # Happines

# %%
dummy = {}
for i in df.happiness:
    for j in i:
        try:
            dummy[j].append(i[j])
        except:
            dummy[j] = [i[j]]

dum = {}
for i in dummy:
    dum[i] = {}
    dum[i]['Number_of'] = []
    dum[i]['Count'] = []
    for j,k in Counter(dummy[i]).items():
            dum[i]['Number_of'].append(j)
            dum[i]['Count'].append(k)
    dum[i] = pd.DataFrame(dum[i])
    
Count_Happines = dum
    
for i in Count_Happines.keys():
    f,ax = plt.subplots(1,1,figsize=(15,7),dpi=120)
    ax = sbn.barplot(x='Number_of',y='Count',data=Count_Happines[i])
    ax.tick_params(axis = 'x', rotation = 0)
    ax.set_title('2018 '+i)
    f.tight_layout()
    f.savefig(fname='img/2018/'+i+'dist_2018.png',format='png',dpi=150)
    plt.show()

# %% [markdown]
# # Opinions

# %%
dummy = {}
for i in df.opinions:
    for j in i:
        try:
            dummy[j].append(i[j])
        except:
            dummy[j] = [i[j]]

dum = {}
for i in dummy:
    dum[i] = {}
    dum[i]['Complexity/Affiniy'] = []
    dum[i]['Count'] = []
    for j,k in Counter(dummy[i]).items():
            dum[i]['Complexity/Affiniy'].append(j)
            dum[i]['Count'].append(k)
    dum[i] = pd.DataFrame(dum[i])

Opinions_dict_DF = dum

for i in Opinions_dict_DF:
    f,ax = plt.subplots(1,1,figsize=(15,7),dpi=120)
    ax = sbn.barplot(x='Complexity/Affiniy',y='Count',data=Opinions_dict_DF[i])
    ax.tick_params(axis = 'x', rotation = 0)
    ax.set_title('2018 '+i)
    f.tight_layout()
    f.savefig(fname='img/2018/'+i+'dist_2018.png',format='png',dpi=150)
    plt.show()
